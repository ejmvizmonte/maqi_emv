# %%
import os

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %matplotlib inline

from scipy.stats import gamma, poisson

import epyestim
import epyestim.covid19 as covid19

# %%
ph_cases = pd.read_csv("phcasecount.csv", parse_dates=["DateRepConf"]).set_index("DateRepConf")["CaseCode"]

# %%
ph_rt = covid19.r_covid(ph_cases)

ph_rt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-c5af13bafef6> in <module>
# ----> 1 ph_rt = covid19.r_covid(ph_cases)
#       2
#       3 ph_rt
#
# ~\anaconda3\lib\site-packages\epyestim\covid19.py in r_covid(confirmed_cases, gt_distribution, delay_distribution, a_prior, b_prior, smoothing_window, r_window_size, r_interval_dates, n_samples, quantiles, auto_cutoff)
#      69     with default parameters for Covid-19.
#      70     """
# ---> 71     return bagging_r(
#      72         confirmed_cases,
#      73         gt_distribution=gt_distribution,
#
# ~\anaconda3\lib\site-packages\epyestim\main.py in bagging_r(confirmed_cases, gt_distribution, delay_distribution, a_prior, b_prior, smoothing_window, r_window_size, r_interval_dates, n_samples, quantiles, auto_cutoff)
#     143     bag = []
#     144     for _ in range(n_samples):
# --> 145         posterior_r = sample_r(
#     146             confirmed_cases=confirmed_cases,
#     147             gt_distribution=gt_distribution,
#
# ~\anaconda3\lib\site-packages\epyestim\main.py in sample_r(confirmed_cases, gt_distribution, delay_distribution, a_prior, b_prior, smoothing_window, r_window_size, r_interval_dates)
#      31     bs_confirmed_cases = bootstrap.bootstrap_series(confirmed_cases)
#      32     sm_bs_confirmed_cases = smoothen.smoothen_series(bs_confirmed_cases, smoothing_window)
# ---> 33     max_likelihood_infections = deconvolution.deconvolve_series(sm_bs_confirmed_cases, delay_distribution)
#      34     posterior_reproduction_number = estimate_r.estimate_r(
#      35         infections_ts=max_likelihood_infections,
#
# ~\anaconda3\lib\site-packages\epyestim\deconvolution.py in deconvolve_series(ser, delay_distrb)
#      73     for _ in range(100):
#      74         exp_obs_array = delay_kernel.dot(ser_deconvolved)
# ---> 75         expected_observed = pd.Series(exp_obs_array[(k - 1):], index=ser.index)
#      76         mD_overE = delay_kernel[(k - 1):, :] * (ser / expected_observed).values.reshape(-1, 1)
#      77         ser_deconvolved = (ser_deconvolved / q) * np.sum(mD_overE, axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     440                 index = default_index(len(data))
#     441             elif is_list_like(data):
# --> 442                 com.require_length_match(data, index)
#     443
#     444             # create/copy the manager
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (707) does not match length of index (678)

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 4))

ph_rt.loc[:,'Q0.5'].plot(ax=ax, color='red')
ax.fill_between(ph_rt.index, 
                    ph_rt['Q0.025'], 
                    ph_rt['Q0.975'], 
                    color='red', alpha=0.2)
ax.set_xlabel('date')
ax.set_ylabel('R(t) with 95%-CI')
ax.set_ylim([0,3])
ax.axhline(y=1)
ax.set_title('Estimate of time-varying effective reproduction number for NCR')
plt.show()

# %%
#before Cori et al.
ph_rt_0 = covid19.r_covid(ph_cases, auto_cutoff=False)

ph_rt_0.tail()
# Out:
#               cases    R_mean     R_var    Q0.025      Q0.5    Q0.975
# 2022-01-07  13732.0  1.281170  0.000026  1.271266  1.281163  1.291112
# 2022-01-08  16320.0  1.235193  0.000023  1.225793  1.235187  1.244612
# 2022-01-09  17093.0  1.178221  0.000021  1.169311  1.178215  1.187161
# 2022-01-10  18764.0  1.111519  0.000018  1.103113  1.111513  1.119955
# 2022-01-11   1939.0  1.064481  0.000017  1.056432  1.064476  1.072567

# %%
fig, ax = plt.subplots(1,1, figsize=(12, 4))

ph_rt_0.loc[:,'Q0.5'].plot(ax=ax, color='blue')
ax.fill_between(ph_rt_0.index, 
                    ph_rt_0['Q0.025'], 
                    ph_rt_0['Q0.975'], 
                    color='green', alpha=0.2)
ax.set_xlabel('date')
ax.set_ylabel('R(t) with 95%-CI')
ax.set_ylim([0,3])
ax.axhline(y=1)
ax.set_title('Estimate of time-varying effective reproduction number for NCR')
plt.show()

# %%
ph_rt.to_csv("ph_rt.csv")
