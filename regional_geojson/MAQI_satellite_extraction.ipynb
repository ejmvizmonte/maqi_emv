# %% [markdown]
# # Sentinel Hub Feature Info Service (FIS)
#
# A statistical summary of satellite indices can be requested via the FIS feature. Examples of extracting time-series statistics data of Sentinel-2 and Sentinel-5P indices are provided.<br>
#
# **Note: Cloud mask values have been included along with the obtained statistics values of Sentinel-2 indices in the following examples.**

# %%
# import libraries
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from shapely.geometry import Polygon
from shapely.ops import cascaded_union
import geopandas as gpd


from sentinelhub import FisRequest, BBox, Geometry, CRS, WcsRequest, CustomUrlParam, \
    DataCollection, HistogramType, bbox_to_dimensions
from sentinelhub.time_utils import parse_time
from sentinelhub import DataCollection

# %% [markdown]
# # sentinel hub configurations
# For the instance ID

# %%
from sentinelhub import SHConfig


INSTANCE_ID = '3704e2d2-43dc-4f34-a563-13ec19dff111'  # In case you put instance ID into configuration file you can leave this unchanged

if INSTANCE_ID:
    config = SHConfig()
    config.instance_id = INSTANCE_ID
else:
    config = None

# %%
def fis_data_to_dataframe(fis_data):
    """ Creates a DataFrame from list of FIS responses
    """
    COLUMNS = ['channel', 'date', 'min', 'max', 'mean', 'stDev']
    data = []

    for fis_response in fis_data:
        for channel, channel_stats in fis_response.items():
            for stat in channel_stats:
                row = [int(channel[1:]), parse_time(stat['date'])]

                for column in COLUMNS[2:]:
                    row.append(stat['basicStats'][column])

                data.append(row)

    return pd.DataFrame(data, columns=COLUMNS).sort_values(['channel', 'date'])

# %%
# convert to clean df ready for analysis
def clean_df (json_stats):
    raw_df_stats = fis_data_to_dataframe(json_stats).reset_index(drop=True)
    index_df = raw_df_stats[raw_df_stats.channel ==0]
    cloud_df = raw_df_stats[raw_df_stats.channel ==1]
    cloud_df = cloud_df.drop(['channel'], axis=1).add_suffix('_clm')
    merged_df = pd.merge(index_df, cloud_df, left_on ='date', right_on = 'date_clm', how='outer')
    clean_merged_df = merged_df.drop(['channel', 'date_clm'], axis=1)
    return clean_merged_df

# %% [markdown]
# ## Parameters of FIS request
#
#
# * `layer` -   name of the layer defined in Sentinel Hub Configurator.
# * `geometry_list` - list of geometry objects (BBox or Geometry), statistics will be calculated for each of them separately
# * `time` - statistics will be calculated for each acquisition in the give time interval separately
# * `resolution` - spatial resolution on which to calculate statistics
# * `data_folder` - optional parameter for specifying location where the data should be saved locally
# * `bins` - The number of bins (a positive integer) in the histogram. When this parameter is absent, no histogram is computed.
# * `histogram_type` - ways of dividing values into bins currently supported: EQUIDISTANT, EQUALFREQUENCY, or STREAMING

# %% [markdown]
# ## Sentinel Hub Configuration
#
# For the Sentinel-5P layer NO2, refer to **FIS-request** configuration instance

# %%
# read single_region geojson in geopandas
single_region = gpd.read_file("Metropolitan Manila.geojson")
single_region_geometry = Geometry(single_region.geometry.values[0], crs=CRS.WGS84)

# %%
# initialize request to obtain basic stats and histogram values
# warning if the timeline is to long there if error timeout at their server
single_region_geometry_n = FisRequest(
    data_collection=DataCollection.SENTINEL5P,
    layer='NO2_SENTINEL5P',
    geometry_list=[single_region_geometry],
    time=('2020-06-20', '2020-12-31'),
    resolution='1000m',
    config=config
)

single_region_geometry_stats_n = single_region_geometry_n.get_data()
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\sentinelhub\api\fis.py:97: SHDeprecationWarning: Fis service is being deprecated in favour of SentinelHubStatistical. Although no immediate action is needed as FIS is still supported, consider switching to Statistical API because it provides additional functionalities.
#   warnings.warn(message, category=SHDeprecationWarning)

# %%
# request will return json output
single_region_geometry_stats_n
# Out:
# [{'C0': [{'date': '2020-12-31',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.46948389046132794,
#      'stDev': 0.3963882794745913}},
#    {'date': '2020-12-29',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5655663656777348,
#      'stDev': 0.3051516493130625}},
#    {'date': '2020-12-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-26',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-25',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-12-24',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4245163145508753,
#      'stDev': 0.4042670376942354}},
#    {'date': '2020-12-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.2878771019818697,
#      'stDev': 0.40759498173181774}},
#    {'date': '2020-12-22',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-21',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-18',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-12-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-16',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4805015010253483,
#      'stDev': 0.41269165793541557}},
#    {'date': '2020-12-15',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-12-14',
#     'basicStats': {'min': 0.0,
#      'max': 0.7931792736053467,
#      'mean': 0.07076428771018978,
#      'stDev': 0.19508018740001523}},
#    {'date': '2020-12-13',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.7186759585821175,
#      'stDev': 0.22168969372002348}},
#    {'date': '2020-12-12',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.39084769435316685,
#      'stDev': 0.4143812837073935}},
#    {'date': '2020-12-11',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3490624010303181,
#      'stDev': 0.3323703745671986}},
#    {'date': '2020-12-10',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-09',
#     'basicStats': {'min': 0.0,
#      'max': 0.5,
#      'mean': 0.24687500000000007,
#      'stDev': 0.249980467987001}},
#    {'date': '2020-12-08',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.08333333333333334,
#      'stDev': 0.2763853991962833}},
#    {'date': '2020-12-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-06',
#     'basicStats': {'min': 0.0,
#      'max': 0.0725630521774292,
#      'mean': 0.00138876654885032,
#      'stDev': 0.009942055472551357}},
#    {'date': '2020-12-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-04',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-03',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-02',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5133513446182829,
#      'stDev': 0.30253023839759224}},
#    {'date': '2020-12-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-30',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-11-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-26',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-11-25',
#     'basicStats': {'min': 0.0,
#      'max': 0.6139421463012695,
#      'mean': 0.16529211631188018,
#      'stDev': 0.2723202396817662}},
#    {'date': '2020-11-24',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.10850439882697958,
#      'stDev': 0.3110163890571932}},
#    {'date': '2020-11-23',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-22',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.2625862972959419,
#      'stDev': 0.3681032623479064}},
#    {'date': '2020-11-21',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.21757446388162782,
#      'stDev': 0.31155609208334434}},
#    {'date': '2020-11-20',
#     'basicStats': {'min': 0.0,
#      'max': 0.9685996770858765,
#      'mean': 0.3768880707877024,
#      'stDev': 0.2916918213201082}},
#    {'date': '2020-11-19',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3301402290702844,
#      'stDev': 0.3358708604020099}},
#    {'date': '2020-11-18',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-11-17',
#     'basicStats': {'min': 0.0,
#      'max': 0.5,
#      'mean': 0.05967078189300406,
#      'stDev': 0.16209499910478298}},
#    {'date': '2020-11-16',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.40426893488486654,
#      'stDev': 0.37029595856677333}},
#    {'date': '2020-11-15',
#     'basicStats': {'min': 0.0,
#      'max': 0.14899174869060516,
#      'mean': 0.07542191652788058,
#      'stDev': 0.06402778083636587}},
#    {'date': '2020-11-14',
#     'basicStats': {'min': 0.0,
#      'max': 0.9928359389305115,
#      'mean': 0.1082812662657143,
#      'stDev': 0.25495434999629457}},
#    {'date': '2020-11-13',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-11-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-10',
#     'basicStats': {'min': 0.0,
#      'max': 0.1134568452835083,
#      'mean': 0.09163822119052592,
#      'stDev': 0.04471487337235404}},
#    {'date': '2020-11-09',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5562691431955474,
#      'stDev': 0.36644266066342956}},
#    {'date': '2020-11-08',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-11-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-06',
#     'basicStats': {'min': 0.0,
#      'max': 0.8175230026245117,
#      'mean': 0.07744648639696194,
#      'stDev': 0.18273564744620527}},
#    {'date': '2020-11-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-04',
#     'basicStats': {'min': 0.5, 'max': 0.5, 'mean': 0.5, 'stDev': 0.0}},
#    {'date': '2020-11-03',
#     'basicStats': {'min': 0.9061737060546875,
#      'max': 0.9061737060546875,
#      'mean': 0.9061737060546875,
#      'stDev': 0.0}},
#    {'date': '2020-11-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-31',
#     'basicStats': {'min': 0.0,
#      'max': 0.2838532328605652,
#      'mean': 0.03664934259700022,
#      'stDev': 0.08716466159707459}},
#    {'date': '2020-10-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4762046854396205,
#      'stDev': 0.3576085737572211}},
#    {'date': '2020-10-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-28',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4983161708764864,
#      'stDev': 0.48965697784355305}},
#    {'date': '2020-10-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-26',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-25',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-24',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.402357285123729,
#      'stDev': 0.37294527939521144}},
#    {'date': '2020-10-22',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-10-21',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-10-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-18',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-16',
#     'basicStats': {'min': 0.0,
#      'max': 0.6445116996765137,
#      'mean': 0.04940112006379314,
#      'stDev': 0.15750222848418802}},
#    {'date': '2020-10-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-14',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-13',
#     'basicStats': {'min': 0.0,
#      'max': 0.7536641359329224,
#      'mean': 0.2844595025181769,
#      'stDev': 0.28749926438705875}},
#    {'date': '2020-10-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-10',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-10-09',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-08',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-06',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-05',
#     'basicStats': {'min': 0.0,
#      'max': 0.25436246395111084,
#      'mean': 0.019783747196197493,
#      'stDev': 0.06812375525385854}},
#    {'date': '2020-10-04',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.37707133714155844,
#      'stDev': 0.3861979509846639}},
#    {'date': '2020-10-03',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4697907690436411,
#      'stDev': 0.3245857673507819}},
#    {'date': '2020-10-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.45121585571517553,
#      'stDev': 0.3780155702615653}},
#    {'date': '2020-09-29',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.45553239485988883,
#      'stDev': 0.3467326343505716}},
#    {'date': '2020-09-28',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.551806925817923,
#      'stDev': 0.32316106179675635}},
#    {'date': '2020-09-27',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5503140924678699,
#      'stDev': 0.4180022791774254}},
#    {'date': '2020-09-26',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.45643238439116357,
#      'stDev': 0.3849500380328818}},
#    {'date': '2020-09-25',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-24',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5373131089112493,
#      'stDev': 0.31608285762163135}},
#    {'date': '2020-09-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3576813391536917,
#      'stDev': 0.3507436644075505}},
#    {'date': '2020-09-22',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6178738182403624,
#      'stDev': 0.28435844304770086}},
#    {'date': '2020-09-21',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3161780978366733,
#      'stDev': 0.3982568235296163}},
#    {'date': '2020-09-20',
#     'basicStats': {'min': 0.0,
#      'max': 0.9226082563400269,
#      'mean': 0.1889743909348536,
#      'stDev': 0.31661074638540826}},
#    {'date': '2020-09-19',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5361186192975834,
#      'stDev': 0.4279148427057885}},
#    {'date': '2020-09-18',
#     'basicStats': {'min': 0.0,
#      'max': 0.691769003868103,
#      'mean': 0.1093415915966034,
#      'stDev': 0.1838151118455365}},
#    {'date': '2020-09-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-16',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-14',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-09-13',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.23766989363086183,
#      'stDev': 0.32664791639217516}},
#    {'date': '2020-09-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-11',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.7921877814291035,
#      'stDev': 0.25614220494494483}},
#    {'date': '2020-09-10',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.7032131036763553,
#      'stDev': 0.2700449881778336}},
#    {'date': '2020-09-09',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.05127564395661467,
#      'stDev': 0.13552499513412486}},
#    {'date': '2020-09-08',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3293330153655112,
#      'stDev': 0.38546827143870344}},
#    {'date': '2020-09-07',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6715272153655539,
#      'stDev': 0.28195104879968363}},
#    {'date': '2020-09-06',
#     'basicStats': {'min': 0.0,
#      'max': 0.38700300455093384,
#      'mean': 0.045368657611493016,
#      'stDev': 0.11713142004513086}},
#    {'date': '2020-09-05',
#     'basicStats': {'min': 0.0,
#      'max': 0.7732604742050171,
#      'mean': 0.29168760860533344,
#      'stDev': 0.27753031835927916}},
#    {'date': '2020-09-04',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6237299748127837,
#      'stDev': 0.4092867480659347}},
#    {'date': '2020-09-03',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6813220891356468,
#      'stDev': 0.3287679514474477}},
#    {'date': '2020-09-02',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.28198012517429505,
#      'stDev': 0.38218327794676527}},
#    {'date': '2020-09-01',
#     'basicStats': {'min': 0.0,
#      'max': 0.5740108489990234,
#      'mean': 0.06036082313629441,
#      'stDev': 0.13150235665972826}},
#    {'date': '2020-08-31',
#     'basicStats': {'min': 0.0,
#      'max': 0.1983470469713211,
#      'mean': 0.038301409107750865,
#      'stDev': 0.07028660288656516}},
#    {'date': '2020-08-30',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-27',
#     'basicStats': {'min': 0.0,
#      'max': 0.5437390804290771,
#      'mean': 0.05050068147988488,
#      'stDev': 0.13037803296671022}},
#    {'date': '2020-08-26',
#     'basicStats': {'min': 0.0,
#      'max': 0.19125618040561676,
#      'mean': 0.0213790226203563,
#      'stDev': 0.052744439467501875}},
#    {'date': '2020-08-25',
#     'basicStats': {'min': 0.0,
#      'max': 0.2985074520111084,
#      'mean': 0.01251683089754328,
#      'stDev': 0.05983056278159077}},
#    {'date': '2020-08-24',
#     'basicStats': {'min': 0.0,
#      'max': 0.6492959260940552,
#      'mean': 0.12570747489476713,
#      'stDev': 0.20961152144989686}},
#    {'date': '2020-08-23',
#     'basicStats': {'min': 0.0,
#      'max': 0.8284573554992676,
#      'mean': 0.12536994861956272,
#      'stDev': 0.21229772870643454}},
#    {'date': '2020-08-22',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4411177817184432,
#      'stDev': 0.40180800858878396}},
#    {'date': '2020-08-21',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-18',
#     'basicStats': {'min': 0.037835050374269485,
#      'max': 0.06949201226234436,
#      'mean': 0.05001080494660597,
#      'stDev': 0.015401246671917073}},
#    {'date': '2020-08-17',
#     'basicStats': {'min': 0.540343701839447,
#      'max': 1.0,
#      'mean': 0.8334808226615664,
#      'stDev': 0.20356301359854428}},
#    {'date': '2020-08-16',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-14',
#     'basicStats': {'min': 0.025263650342822075,
#      'max': 0.025263650342822075,
#      'mean': 0.025263650342822075,
#      'stDev': 0.0}},
#    {'date': '2020-08-13',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3503258351151269,
#      'stDev': 0.46623306023419775}},
#    {'date': '2020-08-12',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-08-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-10',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5321628103440414,
#      'stDev': 0.3819913267323712}},
#    {'date': '2020-08-09',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-08',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-06',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-04',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3152871348584692,
#      'stDev': 0.3441198356798293}},
#    {'date': '2020-08-03',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5823128623505162,
#      'stDev': 0.24130693731543987}},
#    {'date': '2020-08-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-31',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-30',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-27',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.519854250971159,
#      'stDev': 0.3601393692338722}},
#    {'date': '2020-07-26',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4756870757049231,
#      'stDev': 0.38365682896675835}},
#    {'date': '2020-07-25',
#     'basicStats': {'min': 0.0777347981929779,
#      'max': 1.0,
#      'mean': 0.7360148265123675,
#      'stDev': 0.2596475227997455}},
#    {'date': '2020-07-24',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-07-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.2625810729965476,
#      'stDev': 0.3752126038090809}},
#    {'date': '2020-07-22',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-21',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.41841806285896666,
#      'stDev': 0.3964760875868385}},
#    {'date': '2020-07-20',
#     'basicStats': {'min': 0.0,
#      'max': 0.33429771661758423,
#      'mean': 0.07997760604285771,
#      'stDev': 0.12470144539906941}},
#    {'date': '2020-07-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-18',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.05250822420742736,
#      'stDev': 0.2033468764985986}},
#    {'date': '2020-07-17',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.028208101189883268,
#      'stDev': 0.08629509493581866}},
#    {'date': '2020-07-16',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.12053001316164799,
#      'stDev': 0.25248522564331327}},
#    {'date': '2020-07-15',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6442059019638084,
#      'stDev': 0.3613112989322205}},
#    {'date': '2020-07-14',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.525605299089053,
#      'stDev': 0.3191842055637054}},
#    {'date': '2020-07-13',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-11',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5705040557516939,
#      'stDev': 0.3496238071240355}},
#    {'date': '2020-07-10',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6324291163354845,
#      'stDev': 0.3420884029169669}},
#    {'date': '2020-07-09',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.44482506228618546,
#      'stDev': 0.37014617289178253}},
#    {'date': '2020-07-08',
#     'basicStats': {'min': 0.0,
#      'max': 0.5,
#      'mean': 0.04634146341463415,
#      'stDev': 0.1449937946117254}},
#    {'date': '2020-07-07',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.018604651162790715,
#      'stDev': 0.13512408415194377}},
#    {'date': '2020-07-06',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4407909275561393,
#      'stDev': 0.4105053953203792}},
#    {'date': '2020-07-05',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6363962983620488,
#      'stDev': 0.30156045447904756}},
#    {'date': '2020-07-04',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5037196966631169,
#      'stDev': 0.3035697008911049}},
#    {'date': '2020-07-03',
#     'basicStats': {'min': 0.0,
#      'max': 0.9230542778968811,
#      'mean': 0.24871837790050202,
#      'stDev': 0.35970953241489506}},
#    {'date': '2020-07-02',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4189568057737716,
#      'stDev': 0.3911345879628168}},
#    {'date': '2020-07-01',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5266927989916478,
#      'stDev': 0.33152266627493426}},
#    {'date': '2020-06-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.24956375989131643,
#      'stDev': 0.33101954510663156}},
#    {'date': '2020-06-29',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4396435849533225,
#      'stDev': 0.4018775265118111}},
#    {'date': '2020-06-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-06-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-06-26',
#     'basicStats': {'min': 0.0,
#      'max': 0.6533889174461365,
#      'mean': 0.012328092782002576,
#      'stDev': 0.08889914130837552}},
#    {'date': '2020-06-25',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4610658140433615,
#      'stDev': 0.3263912491413377}},
#    {'date': '2020-06-24',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6604060424912365,
#      'stDev': 0.28669310234074896}},
#    {'date': '2020-06-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5434173792236298,
#      'stDev': 0.22124946211713153}},
#    {'date': '2020-06-22',
#     'basicStats': {'min': 0.0,
#      'max': 0.3331018388271332,
#      'mean': 0.061861770067896164,
#      'stDev': 0.12953528772803286}},
#    {'date': '2020-06-21',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.42682206642596027,
#      'stDev': 0.41569405689684413}},
#    {'date': '2020-06-20',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5621097814776094,
#      'stDev': 0.30353294225268784}}],
#   'C1': [{'date': '2020-12-31',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5853430146742543,
#      'stDev': 0.36588466354656407}},
#    {'date': '2020-12-29',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4940356416948911,
#      'stDev': 0.462014913416852}},
#    {'date': '2020-12-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-26',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-25',
#     'basicStats': {'min': 0.0,
#      'max': 0.8011084198951721,
#      'mean': 0.3958530847032,
#      'stDev': 0.3311121217349065}},
#    {'date': '2020-12-24',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5574739449096465,
#      'stDev': 0.3492259043349426}},
#    {'date': '2020-12-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6766669905571563,
#      'stDev': 0.31352231873667896}},
#    {'date': '2020-12-22',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-21',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-18',
#     'basicStats': {'min': 0.32762759923934937,
#      'max': 0.9136353135108948,
#      'mean': 0.6111797190481617,
#      'stDev': 0.29285137008035733}},
#    {'date': '2020-12-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-16',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6584074498908739,
#      'stDev': 0.36142233199190504}},
#    {'date': '2020-12-15',
#     'basicStats': {'min': 0.44788143038749695,
#      'max': 0.6764808893203735,
#      'mean': 0.5281186960637569,
#      'stDev': 0.10377948740881997}},
#    {'date': '2020-12-14',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6224735867232085,
#      'stDev': 0.29373462740371065}},
#    {'date': '2020-12-13',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.2798310632381258,
#      'stDev': 0.4083608277569621}},
#    {'date': '2020-12-12',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.44929000349288944,
#      'stDev': 0.3676482114115628}},
#    {'date': '2020-12-11',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5904056834044795,
#      'stDev': 0.3849633991800558}},
#    {'date': '2020-12-10',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-09',
#     'basicStats': {'min': 0.0,
#      'max': 0.9001144170761108,
#      'mean': 0.27320315763354297,
#      'stDev': 0.38843807786250906}},
#    {'date': '2020-12-08',
#     'basicStats': {'min': 0.0,
#      'max': 0.8478848338127136,
#      'mean': 0.40421477115402604,
#      'stDev': 0.36308420957069}},
#    {'date': '2020-12-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-06',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.39070018584078003,
#      'stDev': 0.2983356835456614}},
#    {'date': '2020-12-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-04',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-03',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-12-02',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4619486323774676,
#      'stDev': 0.46534075427867977}},
#    {'date': '2020-12-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-30',
#     'basicStats': {'min': 0.003618502989411354,
#      'max': 0.6165423393249512,
#      'mean': 0.413384930439605,
#      'stDev': 0.1810591443060035}},
#    {'date': '2020-11-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-26',
#     'basicStats': {'min': 0.2338557094335556,
#      'max': 0.6237615942955017,
#      'mean': 0.3785425241916411,
#      'stDev': 0.13310292774774096}},
#    {'date': '2020-11-25',
#     'basicStats': {'min': 0.10293205082416534,
#      'max': 1.0,
#      'mean': 0.4463928550099716,
#      'stDev': 0.3733906433638539}},
#    {'date': '2020-11-24',
#     'basicStats': {'min': 0.011889156885445118,
#      'max': 0.9143226146697998,
#      'mean': 0.5466205684599247,
#      'stDev': 0.19956827497912366}},
#    {'date': '2020-11-23',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-22',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6704820229049112,
#      'stDev': 0.3055352781512462}},
#    {'date': '2020-11-21',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.7089256599167725,
#      'stDev': 0.31831224477969966}},
#    {'date': '2020-11-20',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.431817342863454,
#      'stDev': 0.4401804366212487}},
#    {'date': '2020-11-19',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5852739232607551,
#      'stDev': 0.3776206685896371}},
#    {'date': '2020-11-18',
#     'basicStats': {'min': 0.0,
#      'max': 0.035906147211790085,
#      'mean': 0.010258899203368596,
#      'stDev': 0.016220743884365847}},
#    {'date': '2020-11-17',
#     'basicStats': {'min': 0.0,
#      'max': 0.6292224526405334,
#      'mean': 0.29839090625812975,
#      'stDev': 0.230864609350375}},
#    {'date': '2020-11-16',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.579601940674626,
#      'stDev': 0.39615969304387383}},
#    {'date': '2020-11-15',
#     'basicStats': {'min': 0.45359179377555847,
#      'max': 1.0,
#      'mean': 0.8633357034789192,
#      'stDev': 0.1805531077709689}},
#    {'date': '2020-11-14',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3760871025946388,
#      'stDev': 0.3713783490165459}},
#    {'date': '2020-11-13',
#     'basicStats': {'min': 0.0,
#      'max': 0.952436089515686,
#      'mean': 0.4335382190957385,
#      'stDev': 0.30789800124698957}},
#    {'date': '2020-11-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-10',
#     'basicStats': {'min': 0.406996488571167,
#      'max': 1.0,
#      'mean': 0.885960863186763,
#      'stDev': 0.2337106840635543}},
#    {'date': '2020-11-09',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5501552287643479,
#      'stDev': 0.4578405362975834}},
#    {'date': '2020-11-08',
#     'basicStats': {'min': 0.00840277224779129,
#      'max': 0.8224974274635315,
#      'mean': 0.6373588852276487,
#      'stDev': 0.32145943464559207}},
#    {'date': '2020-11-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-06',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6052780442209134,
#      'stDev': 0.33043084571455605}},
#    {'date': '2020-11-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-04',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-11-03',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-31',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6058066341820664,
#      'stDev': 0.281687422943333}},
#    {'date': '2020-10-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.8279487982118889,
#      'stDev': 0.27405806748477923}},
#    {'date': '2020-10-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-28',
#     'basicStats': {'min': 0.13381165266036987,
#      'max': 1.0,
#      'mean': 0.8251126335378277,
#      'stDev': 0.28175329086195106}},
#    {'date': '2020-10-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-26',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-25',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-24',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-23',
#     'basicStats': {'min': 0.30569690465927124,
#      'max': 1.0,
#      'mean': 0.8646078204874191,
#      'stDev': 0.20362231292738306}},
#    {'date': '2020-10-22',
#     'basicStats': {'min': 0.8252232670783997,
#      'max': 0.8252232670783997,
#      'mean': 0.8252232670783997,
#      'stDev': 0.0}},
#    {'date': '2020-10-21',
#     'basicStats': {'min': 0.823785126209259,
#      'max': 0.823785126209259,
#      'mean': 0.823785126209259,
#      'stDev': 0.0}},
#    {'date': '2020-10-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-18',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-16',
#     'basicStats': {'min': 0.05834996700286865,
#      'max': 1.0,
#      'mean': 0.5482492757835002,
#      'stDev': 0.2858010032811774}},
#    {'date': '2020-10-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-14',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-13',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5865583090782162,
#      'stDev': 0.38229588675013393}},
#    {'date': '2020-10-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-10',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-10-09',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-08',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-06',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-05',
#     'basicStats': {'min': 0.0015844726003706455,
#      'max': 1.0,
#      'mean': 0.4752110334630646,
#      'stDev': 0.25972263902450016}},
#    {'date': '2020-10-04',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6086120405778844,
#      'stDev': 0.37508373051682425}},
#    {'date': '2020-10-03',
#     'basicStats': {'min': 0.3329470455646515,
#      'max': 1.0,
#      'mean': 0.9209172901944218,
#      'stDev': 0.1512827000958175}},
#    {'date': '2020-10-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-30',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6236315833670756,
#      'stDev': 0.41936804973522823}},
#    {'date': '2020-09-29',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.576710805582674,
#      'stDev': 0.4442241460599736}},
#    {'date': '2020-09-28',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5853348024666103,
#      'stDev': 0.4453426777640092}},
#    {'date': '2020-09-27',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.630981285504017,
#      'stDev': 0.35415461227228623}},
#    {'date': '2020-09-26',
#     'basicStats': {'min': 0.48451051115989685,
#      'max': 1.0,
#      'mean': 0.8455400055231056,
#      'stDev': 0.18644026488259216}},
#    {'date': '2020-09-25',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-24',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.57325385504921,
#      'stDev': 0.44172032662488164}},
#    {'date': '2020-09-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.8234527957054872,
#      'stDev': 0.2776515736622463}},
#    {'date': '2020-09-22',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.36284981656833504,
#      'stDev': 0.40474371402490783}},
#    {'date': '2020-09-21',
#     'basicStats': {'min': 0.3436415493488312,
#      'max': 1.0,
#      'mean': 0.7422748077909148,
#      'stDev': 0.23594547447460018}},
#    {'date': '2020-09-20',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.45165687157724926,
#      'stDev': 0.38717521745585937}},
#    {'date': '2020-09-19',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6246486904076187,
#      'stDev': 0.3661145047380587}},
#    {'date': '2020-09-18',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4907316932499054,
#      'stDev': 0.36767730711701835}},
#    {'date': '2020-09-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-16',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-14',
#     'basicStats': {'min': 0.0,
#      'max': 0.8683199286460876,
#      'mean': 0.20825964360605945,
#      'stDev': 0.20172808941379214}},
#    {'date': '2020-09-13',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.7133133917757611,
#      'stDev': 0.3040528730494645}},
#    {'date': '2020-09-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-11',
#     'basicStats': {'min': 0.033262018114328384,
#      'max': 1.0,
#      'mean': 0.7456571168670953,
#      'stDev': 0.3870730784804372}},
#    {'date': '2020-09-10',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6327042695014705,
#      'stDev': 0.3915462471269318}},
#    {'date': '2020-09-09',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4897374220599889,
#      'stDev': 0.35748496557401394}},
#    {'date': '2020-09-08',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6208082205258886,
#      'stDev': 0.38013294461872854}},
#    {'date': '2020-09-07',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.44932755124085066,
#      'stDev': 0.4648288903612909}},
#    {'date': '2020-09-06',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.684679841817234,
#      'stDev': 0.25013527407515773}},
#    {'date': '2020-09-05',
#     'basicStats': {'min': 0.5863063931465149,
#      'max': 1.0,
#      'mean': 0.9492218832901189,
#      'stDev': 0.11249278779460249}},
#    {'date': '2020-09-04',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6035940361135965,
#      'stDev': 0.3906487866210271}},
#    {'date': '2020-09-03',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.35743354130536326,
#      'stDev': 0.3820849388642147}},
#    {'date': '2020-09-02',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.666883392244121,
#      'stDev': 0.31267129689072176}},
#    {'date': '2020-09-01',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.7428643788134787,
#      'stDev': 0.2768585445254623}},
#    {'date': '2020-08-31',
#     'basicStats': {'min': 0.0717797800898552,
#      'max': 1.0,
#      'mean': 0.8010425237491582,
#      'stDev': 0.25965673698287967}},
#    {'date': '2020-08-30',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-27',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5067227786068205,
#      'stDev': 0.3649462341380184}},
#    {'date': '2020-08-26',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5186001866091804,
#      'stDev': 0.3633451430555806}},
#    {'date': '2020-08-25',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4020448736136421,
#      'stDev': 0.301732289142103}},
#    {'date': '2020-08-24',
#     'basicStats': {'min': 0.06430653482675552,
#      'max': 1.0,
#      'mean': 0.6919687096328635,
#      'stDev': 0.27316378120543006}},
#    {'date': '2020-08-23',
#     'basicStats': {'min': 0.14017228782176971,
#      'max': 1.0,
#      'mean': 0.7551549781217339,
#      'stDev': 0.2881609308069012}},
#    {'date': '2020-08-22',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.4532684338713888,
#      'stDev': 0.3968286008574532}},
#    {'date': '2020-08-21',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-18',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-17',
#     'basicStats': {'min': 0.5037996768951416,
#      'max': 1.0,
#      'mean': 0.7693648309934706,
#      'stDev': 0.24195159983272946}},
#    {'date': '2020-08-16',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-14',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-13',
#     'basicStats': {'min': 0.008104275912046432,
#      'max': 1.0,
#      'mean': 0.7937096255255562,
#      'stDev': 0.18644240329953832}},
#    {'date': '2020-08-12',
#     'basicStats': {'min': 0.0, 'max': 0.0, 'mean': 0.0, 'stDev': 0.0}},
#    {'date': '2020-08-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-10',
#     'basicStats': {'min': 0.4716126024723053,
#      'max': 1.0,
#      'mean': 0.8179749772272398,
#      'stDev': 0.23410151818299882}},
#    {'date': '2020-08-09',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-08',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-06',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-04',
#     'basicStats': {'min': 0.043781135231256485,
#      'max': 1.0,
#      'mean': 0.7329996568538875,
#      'stDev': 0.3138661487199765}},
#    {'date': '2020-08-03',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.2617090103765057,
#      'stDev': 0.4086998260348289}},
#    {'date': '2020-08-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-31',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-30',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-27',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.504893278089297,
#      'stDev': 0.4363175403060492}},
#    {'date': '2020-07-26',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5602092114760585,
#      'stDev': 0.42669049052651686}},
#    {'date': '2020-07-25',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.49209272655310027,
#      'stDev': 0.46005578428158356}},
#    {'date': '2020-07-24',
#     'basicStats': {'min': 0.0,
#      'max': 0.26994723081588745,
#      'mean': 0.13232843704680178,
#      'stDev': 0.1337288594944834}},
#    {'date': '2020-07-23',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5982060567686266,
#      'stDev': 0.3591039214918706}},
#    {'date': '2020-07-22',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-21',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6004370219728964,
#      'stDev': 0.4202615142954985}},
#    {'date': '2020-07-20',
#     'basicStats': {'min': 0.2338787019252777,
#      'max': 1.0,
#      'mean': 0.7069264213507278,
#      'stDev': 0.2667226523424012}},
#    {'date': '2020-07-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-18',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.3948769514268684,
#      'stDev': 0.3445048563782262}},
#    {'date': '2020-07-17',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.47197925315180195,
#      'stDev': 0.3338023823361288}},
#    {'date': '2020-07-16',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5446692675588627,
#      'stDev': 0.37259598822616824}},
#    {'date': '2020-07-15',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5320542235362676,
#      'stDev': 0.4260479803672824}},
#    {'date': '2020-07-14',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.6776335394092172,
#      'stDev': 0.4133613079270663}},
#    {'date': '2020-07-13',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-11',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5855575065645907,
#      'stDev': 0.4396382677638421}},
#    {'date': '2020-07-10',
#     'basicStats': {'min': 0.0,
#      'max': 1.0,
#      'mean': 0.5237703726105734,
#      'stDev': 0.4220299073188043}},
#    {'date': '2020-07-09',
#     'basicStats': {'min': 0.13646912574768066,
#      'max': 1.0,
#      'mean': 0.8539396519537016,
#      'stDev': 0.2656247579787641}},
#    {'date': '2020-07-08',
# ...
#    {'date': '2020-11-24',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-23',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-22',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-21',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-20',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-19',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-18',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-17',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-16',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-15',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-14',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-13',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-10',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-09',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-08',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-06',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-04',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-03',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-11-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-11-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-31',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-30',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-28',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-26',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-25',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-24',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-23',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-22',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-21',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-18',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-16',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-14',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-13',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-10',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-09',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-08',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-06',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-05',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-04',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-03',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-10-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-10-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-30',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-29',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-28',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-27',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-26',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-25',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-24',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-23',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-22',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-21',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-20',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-19',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-18',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-17',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-16',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-14',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-13',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-09-11',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-10',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-09',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-08',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-07',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-06',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-05',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-04',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-03',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-02',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-09-01',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-31',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-30',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-27',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-26',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-25',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-24',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-23',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-22',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-21',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-20',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-18',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-17',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-16',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-15',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-14',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-13',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-12',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-11',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-10',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-09',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-08',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-07',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-06',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-05',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-04',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-03',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-08-02',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-08-01',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-31',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-30',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-29',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-27',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-26',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-25',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-24',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-23',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-22',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-21',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-20',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-19',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-18',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-17',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-16',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-15',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-14',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-13',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-12',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-07-11',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-10',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-09',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-08',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-07',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-06',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-05',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-04',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-03',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-02',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-07-01',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-30',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-29',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-28',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-06-27',
#     'basicStats': {'min': 'NaN', 'max': 'NaN', 'mean': 'NaN', 'stDev': 'NaN'}},
#    {'date': '2020-06-26',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-25',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-24',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-23',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-22',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-21',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}},
#    {'date': '2020-06-20',
#     'basicStats': {'min': 1.0, 'max': 1.0, 'mean': 1.0, 'stDev': 0.0}}]}]

# %%
# Data Frame Cleaning
single_region_stats_clean = clean_df(single_region_geometry_stats_n)
single_region_stats_clean
# Out:
#            date  min       max      mean     stDev min_clm max_clm  mean_clm  \
# 0    2020-06-20  0.0       1.0   0.56211  0.303533     0.0     1.0  0.400873
# 1    2020-06-21  0.0       1.0  0.426822  0.415694     0.0     1.0  0.553039
# 2    2020-06-22  0.0  0.333102  0.061862  0.129535     0.0     1.0  0.479895
# 3    2020-06-23  0.0       1.0  0.543417  0.221249     0.0     1.0  0.174826
# 4    2020-06-24  0.0       1.0  0.660406  0.286693     0.0     1.0  0.458333
# ..          ...  ...       ...       ...       ...     ...     ...       ...
# 190  2020-12-27  NaN       NaN       NaN       NaN     NaN     NaN       NaN
# 191  2020-12-28  NaN       NaN       NaN       NaN     NaN     NaN       NaN
# 192  2020-12-29  0.0       1.0  0.565566  0.305152     0.0     1.0  0.494036
# 193  2020-12-30  0.0       1.0  0.469484  0.396388     0.0     1.0  0.585343
# 194  2020-12-31  NaN       NaN       NaN       NaN     NaN     NaN       NaN
#
#     stDev_clm
# 0    0.457583
# 1    0.395934
# 2    0.377552
# 3    0.343376
# 4    0.433572
# ..        ...
# 190       NaN
# 191       NaN
# 192  0.462015
# 193  0.365885
# 194       NaN
#
# [195 rows x 9 columns]

# %%
# Export to CSV
single_region_stats_clean.to_csv('regional_no2_results/ARMM_region_stats_clean.csv', index=False)

# %% [markdown]
# ## END
